# %% [markdown]
# # Bagging
# * Let's say this is our data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Our weak leanrer will be a onenode decision trees

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # what happend in real ?
# * we will separate the data into small subsets

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Merging them together and take voting

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # After voting the final model will be

# %% [markdown]
# ![image.png](attachment:image.png)
