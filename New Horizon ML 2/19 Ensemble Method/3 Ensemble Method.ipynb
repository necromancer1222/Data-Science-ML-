# %% [markdown]
# # AdaBoost
# ## Data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # the first learner will try to increase the accuracy as possible

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # the second learner will  focus on mistakes of first learner
# ## by punshing the model with increasing the values of mistakes points

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # again the mistakes will be punished by increasing its values

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # So the final model will be by mergin all of them

# %% [markdown]
# ![image.png](attachment:image.png)
