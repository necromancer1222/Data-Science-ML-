# %% [markdown]
# # Introduction

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Bagging
# * Every one will answer in separate way and take the average of the answer if the answer was a value
# * Every one will answer in separate way and take the voting if the answer was (yes) or (no)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # The final model
# ![image.png](attachment:image.png)

# %% [markdown]
# # Boosting
# * It is about give evey body its strong point to answer the question

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # The final model

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Weak learner and strong learner

# %% [markdown]
# ![image.png](attachment:image.png)
