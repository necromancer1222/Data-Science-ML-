# %% [markdown]
# ## Quiz 1
# ![image.png](attachment:image.png)

# %% [markdown]
# ## quiz 2
# ![image.png](attachment:image.png)

# %% [markdown]
# ## quiz 3
# ![image.png](attachment:image.png)

# %% [markdown]
# ## quiz 4
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## quiz 4
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
