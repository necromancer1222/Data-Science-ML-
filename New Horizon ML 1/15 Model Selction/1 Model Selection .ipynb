# %% [markdown]
# # Regression Metrics
# ## Mean Absolute Error

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Mean Squared Error

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## R2 Score

# %% [markdown]
# ### 1- drawing horizontal line to all the points as a simple model
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2- there is abig chance that the mean squared error for the simple model will be larger than the model that we have made
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3- divide the linear reg error to the simple model error
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Example

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
y_true=[1,2,4]
y_pred=[1.3,2.5,3.7]
print("mean abs error =",mean_absolute_error(y_true,y_pred))
print("mean sqrd error =",mean_squared_error(y_true,y_pred))

print("r2_score",r2_score(y_true,y_pred))
# Out:
# mean abs error = 0.36666666666666664
# mean sqrd error = 0.1433333333333333
# r2_score 0.9078571428571429
