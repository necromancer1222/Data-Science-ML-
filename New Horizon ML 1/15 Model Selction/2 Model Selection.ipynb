# %% [markdown]
# # Model Selection: Overfitting vs Underfitting
# ## Type of errors
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Type 1: over simplifing  the problem (Underfitting)
# ### does not do well in the training
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Type 2: over complicating  the problem (overfitting)
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Underfitting example
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Overfitting example
# ### Does great in training but poor in testing
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Underfitting for classification model
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Overfitting for classification model
# ![image.png](attachment:image.png)

# %% [markdown]
# ## underfitting vs good fitting vs overfitting
# ![image.png](attachment:image.png)
