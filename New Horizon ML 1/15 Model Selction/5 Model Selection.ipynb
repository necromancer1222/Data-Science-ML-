# %% [markdown]
# # Grid Search

# %% [markdown]
# ## Hyper parameters for logistic regression
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Hyper parameters for decision trees
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Hyper parameters for SVM
# ![image.png](attachment:image.png)

# %% [markdown]
# ## How th choose between C & kernel ?!!
# ### The answer will be Grid Search
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Grid Search in sklearn

# %%
#1. Import GridSearchCV
from sklearn.model_selection import GridSearchCV

#2. Select the parameters:
parameters = {'kernel':['poly', 'rbf'],'C':[0.1, 1, 10]}

#3. Create a scorer
from sklearn.metrics import make_scorer
from sklearn.metrics import f1_score
scorer = make_scorer(f1_score)

# %%
#4. Create a GridSearch Object with the parameters, and the scorer. Use this object to fit the data

# Create the object.
grid_obj = GridSearchCV(clf, parameters, scoring=scorer)
# Fit the data
grid_fit = grid_obj.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-40bc209cd00b> in <module>
#       2
#       3 # Create the object.
# ----> 4 grid_obj = GridSearchCV(clf, parameters, scoring=scorer)
#       5 # Fit the data
#       6 grid_fit = grid_obj.fit(X, y)
#
# NameError: name 'clf' is not defined

# %%
# 5. Get the best estimator
best_clf = grid_fit.best_estimator_
