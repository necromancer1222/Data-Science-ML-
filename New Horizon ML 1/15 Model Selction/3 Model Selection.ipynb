# %% [markdown]
# # Model Complexity Graph
# ## In this model how many testing and tratining errors ?
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Model Complexity Graph example
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## don't use testing data on your training
# ![image.png](attachment:image.png)

# %% [markdown]
# ## How to choose our correct model without using testning data ?!!
# ## Soluiotn will be : CROSS VALIDATION

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
