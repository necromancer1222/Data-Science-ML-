# %% [markdown]
# # Basic model training
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()

# %% [markdown]
# ## Neural Networks

# %%
from sklearn.neural_network import MLPClassifier
classifier = MLPClassifier()

# %% [markdown]
# ## Decision Trees

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()

# %% [markdown]
# ## Support Vector Machines

# %%
from sklearn.svm import SVC
classifier = SVC()

# %% [markdown]
# ## Example for Logistic Regression

# %%
import numpy as np
import pandas as pd
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline
full_data = pd.read_csv("data.txt")
full_data.head()
# Out:
#         x1        x2  y
# 0  0.78051 -0.063669  0
# 1  0.28774  0.291390  0
# 2  0.40714  0.178780  0
# 3  0.29230  0.421700  0
# 4  0.50922  0.352560  0

# %%
g = sb.FacetGrid(data =full_data, hue = 'y', size = 5)
g.map(plt.scatter, 'x1', 'x2')
g.add_legend()
# Out:
# C:\Users\NH\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
y = full_data['y']
X = full_data.drop('y', axis = 1)
X=np.array(X)
y=np.array(y)
classifier.fit(X,y)
# Out:
# LogisticRegression()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## what is the best model for this data

# %%
import pandas as pd
import numpy as np

# Read the data
data = pd.read_csv('data2.csv')

data.head()
# Out:
#          x1        x2    y
# 0  0.336494 -0.985951  0.0
# 1 -0.011043 -0.105529  1.0
# 2  0.238160 -0.617417  1.0
# 3 -0.366783 -0.713819  1.0
# 4  1.221923 -1.039399  0.0

# %%
g = sb.FacetGrid(data =data, hue = 'y', size = 5)
g.map(plt.scatter, 'x1', 'x2')
g.add_legend()
# Out:
# C:\Users\NH\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Split the data into X and y
X = np.array(data[['x1', 'x2']])
y = np.array(data['y'])


# import statements for the classification algorithms
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# Logistic Regression Classifier
classifier1 = LogisticRegression()
classifier1.fit(X,y)

# Decision Tree Classifier
classifier2 = DecisionTreeClassifier()
classifier2.fit(X,y)

# Support Vector Machine Classifier
classifier3 = SVC()
classifier3.fit(X,y)
# Out:
# SVC()

# %% [markdown]
# ![image.png](attachment:image.png)
